# %% [markdown]
# # Residential Primary Energy Consumption, by Year and Fuel Type 2009

# %% [markdown]
# Following The Data Analysis in Python with Pandas Video
# https://www.youtube.com/watch?v=w26x-z-BdWQ
# And other resources

# %%
from pandas import *
#turn off html
#pandas.set_option(notebook_repr_html=False)
#pandas.set_printoptions(...) is deprecated. Instead, use pandas.set_option.
#figure this out later

#still broken
#pandas.set_option(max_rows=5000)
#also broken.

import pandas
pandas.__version__

#NnOTpandas.set_printoptions(notebook_repr_html=False)  # turn off html, i.e., without table.
#NOTpandas.set_printoptions(max_rows=500)   # getting the summary of the view versus getting everything. Terminal takes time to buffer.

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas
pandas.__version__
# Out:
# '0.14.1'

# %%
Res_Primary_E_Consumption = read_csv('ResPrimaryEnergyConsumptionBtu2.csv')
#Res_Primary_E_Consumption = read_csv('Res Primary Energy Consumption Btu.csv')

# %%
# Drop a column-- for previous file
#http://stackoverflow.com/questions/13411544/delete-column-from-pandas-dataframe
# DF = DF.drop('column_name', 1)
#Res_Primary_E_Consumption = Res_Primary_E_Consumption.drop('Unnamed: 11', 1)
# how to do this permanently? put it with the open file command?

# %%
Res_Primary_E_Consumption.head(10)
#locking up. can't scroll.
# I hate technology.
# remove the html?
# Out:
#    Year  NaturalGas NaturalGas_perc  Petroleum Petroleum_perc  Coal Coal_perc  \
# 0  1980        4.79             30%       1.72            11%  0.03        0%
# 1  1981        4.57             30%       1.52            10%  0.03        0%
# 2  1982        4.68             30%       1.42             9%  0.03        0%
# 3  1983        4.45             29%       1.33             9%  0.03        0%
# 4  1984        4.64             29%       1.51            10%  0.04        0%
# 5  1985        4.51             28%       1.55            10%  0.04        0%
# 6  1986        4.38             28%       1.52            10%  0.04        0%
# 7  1987        4.40             27%       1.60            10%  0.04        0%
# 8  1988        4.72             28%       1.66            10%  0.04        0%
# 9  1989        4.88             28%       1.64             9%  0.03        0%
#
#    Renewable Renewable_perc  Electricity_Sales  Electricity_Losses  \
# ...

# %%
Res_Primary_E_Consumption.tail(10)
# Out:
#     Year  NaturalGas NaturalGas_perc  Petroleum Petroleum_perc  Coal  \
# 46  2026        4.87             22%       0.95             4%  0.01
# 47  2027        4.86             21%       0.94             4%  0.01
# 48  2028        4.85             21%       0.93             4%  0.01
# 49  2029        4.85             21%       0.92             4%  0.01
# 50  2030        4.84             21%       0.91             4%  0.01
# 51  2031        4.83             21%       0.90             4%  0.01
# 52  2032        4.81             21%       0.90             4%  0.01
# 53  2033        4.79             20%       0.89             4%  0.01
# 54  2034        4.78             20%       0.88             4%  0.01
# 55  2035        4.76             20%       0.87             4%  0.01
#
#    Coal_perc  Renewable Renewable_perc  Electricity_Sales  Electricity_Losses  \
# 46        0%       0.54             2%               5.37               10.78
# ...

# %%
# names
#why not showing the summary info as his first example did?
#names.head()
#names[names.year == 1880].tail()
#boolean array in numpy-- scalar operation.
#why not showing the summary info as his first example did?
boys = names[names.sex == 'boy']
girls = names[names.sex == 'girl']

# %%
#names.groupby(['sex','year']).size()
#names.groupby(['year','sex']).size().ix[2000]
Res_Primary_E_Consumption.groupby(['Year','NaturalGas']).size().ix[2000]
#a hierarchical index
# a series.
# Out:
# NaturalGas
# 5.07          1
# dtype: int64

# %%
#names.groupby(['sex','year']).size()
#names.groupby(['year','sex']).size().ix[2000]
Res_Primary_E_Consumption.groupby(['Year','NaturalGas']).size().ix[1980]
#a hierarchical index
# a series.
# Out:
# NaturalGas
# 4.79          1
# dtype: int64

# %%
#names.groupby(['sex','year']).size()
#names.groupby(['year','sex']).size().ix[2000]
Res_Primary_E_Consumption.groupby(['Year','NaturalGas_perc']).size().ix[1980]
#a hierarchical index
# a series. 

#this variable name works. and it seems to accept the highest percent 30%.
# but it seems to have a problem with the datatype later.
# Out:
# NaturalGas_perc
# 30%                1
# dtype: int64

# %%
#boys[boys.year== 2000].prop.idxmax()
# gives the index of the maximum value: idmax
#boys.ix[boys[boys.year== 2000].prop.idxmax()]
# for the whole row
Res_Primary_E_Consumption.ix[Res_Primary_E_Consumption[Res_Primary_E_Consumption.Year== 2000].TOTAL.idxmax()]
# Out:
# Year                       2000
# NaturalGas                 5.07
# NaturalGas_perc             25%
# Petroleum                  1.52
# Petroleum_perc               7%
# Coal                       0.01
# Coal_perc                    0%
# Renewable                  0.49
# Renewable_perc               2%
# Electricity_Sales          4.07
# Electricity_Losses          9.2
# Electricity_Total         13.27
# Electricity_Total_perc      65%
# TOTAL                     20.36
# TOTAL_perc                 100%
# Change_since2010              -
# Name: 20, dtype: object

# %%
def get_max_record(group):
    return group.ix[group.TOTAL.idxmax()]
get_max_record(Res_Primary_E_Consumption)
# Out:
# Year                       2035
# NaturalGas                 4.76
# NaturalGas_perc             20%
# Petroleum                  0.87
# Petroleum_perc               4%
# Coal                       0.01
# Coal_perc                    0%
# Renewable                  0.55
# Renewable_perc               2%
# Electricity_Sales          5.94
# Electricity_Losses        11.56
# Electricity_Total          17.5
# Electricity_Total_perc      74%
# TOTAL                     23.69
# TOTAL_perc                 100%
# Change_since2010           0.3%
# Name: 55, dtype: object

# %%
#Rename a column
# http://stackoverflow.com/questions/11346283/renaming-columns-in-pandas 

# df.columns.values[0]='XX' 
#Res_Primary_E_Consumption.columns.values[1]='NaturalGas'

# %%
#Rename a column
# http://stackoverflow.com/questions/11346283/renaming-columns-in-pandas 

# df.columns.values[0]='XX' 
#Res_Primary_E_Consumption.columns.values[-3]='MYTOTAL'

# %%
#Rename a column
# http://stackoverflow.com/questions/11346283/renaming-columns-in-pandas 

# df.columns.values[0]='XX' 
#Res_Primary_E_Consumption.columns.values[2]='NaturalGas_perc'

# %%
#Rename a column
# http://stackoverflow.com/questions/11346283/renaming-columns-in-pandas 

# df.columns.values[0]='XX' 
#Res_Primary_E_Consumption.columns.values[15]='Growth Rate(2010-Year)'

# %% [markdown]
# ### Top 5 Girls Names in 2005

# %%
#girls[girls.year == 2005].head(40)    
#girls[girls.year == 2005].head(40)
#NO ANALOGOUS NEED IN THIS DATA SET.

# %%
# split by year-- proportion in each year and stack them.
# 
#def get_max_record(group):
 #   return group.ix[group.prop.idxmax()]
#result =boys.groupby('year').apply(get_max_record)     
# my full data is not showing due to html, which I cannot remove.
# diversity of data going up.

def get_max_record(group):
    return group.ix[group.TOTAL.idxmax()]
result =Res_Primary_E_Consumption.groupby('Year').apply(get_max_record)   

#why am I getting this error? The TOTAL column has been renamed to YESTOTAL.
#AttributeError: 'DataFrame' object has no attribute 'YESTOTAL'
#YESTOTAL works beow with result.

#no error when returned to TOTAL.

# %%
# split by year-- proportion in each year and stack them.
# 
#def get_max_record(group):
 #   return group.ix[group.prop.idxmax()]
#result =boys.groupby('year').apply(get_max_record)     
# my full data is not showing due to html, which I cannot remove.
# diversity of data going up.

def get_max_record(group):
    return group.ix[group.NaturalGas.idxmax()]
NG_result =Res_Primary_E_Consumption.groupby('Year').apply(get_max_record)

# %%
# split by year-- proportion in each year and stack them.
# 
#def get_max_record(group):
 #   return group.ix[group.prop.idxmax()]
#result =boys.groupby('year').apply(get_max_record)     
# my full data is not showing due to html, which I cannot remove.
# diversity of data going up.

# NaturalGas
def get_max_record(group):
  #  return group.ix[group.NaturalGas_perc.idxmax()]
    return group.ix[group.Renewable_perc.idxmax()]
NG_result =Res_Primary_E_Consumption.groupby('Year').apply(get_max_record)     

#Renewable_perc
#    return group.ix[group.NaturalGas.idxmax()]
# ??? AttributeError: 'DataFrame' object has no attribute 'NaturalGas'
# Why Not? It has TOTAL

#    return group.ix[group.NaturalGas_perc.idxmax()]
#ValueError: invalid literal for float(): 30%
# does it have this. but is it yeilding an error on this?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-687bf531febe> in <module>()
#      11   #  return group.ix[group.NaturalGas_perc.idxmax()]
#      12     return group.ix[group.Renewable_perc.idxmax()]
# ---> 13 NG_result =Res_Primary_E_Consumption.groupby('Year').apply(get_max_record)
#      14
#      15 #Renewable_perc
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     635             return func(g, *args, **kwargs)
#     636
# --> 637         return self._python_apply_general(f)
#     638
#     639     def _python_apply_general(self, f):
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     639     def _python_apply_general(self, f):
#     640         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# ...

# %% [markdown]
# # First Chart: Shows Increase in diversity of names. Top proportion Decreasing.

# %%
result.TOTAL
# YESTOTAL Works , but not TOTAL.
#AttributeError: 'DataFrame' object has no attribute 'TOTAL'
    
#issue of saving and running order?
# anything else that needs to be saved and run?
# Out:
# Year
# 1980    15.72
# 1981    15.23
# 1982    15.48
# 1983    15.38
# 1984    15.90
# 1985    16.02
# 1986    15.94
# 1987    16.21
# 1988    17.12
# 1989    17.76
# 1990    16.91
# 1991    17.37
# 1992    17.31
# 1993    18.18
# 1994    18.07
# 1995    18.49
# 1996    19.47
# 1997    18.93
# 1998    18.92
# 1999    19.52
# 2000    20.36
# 2001    20.00
# 2002    20.74
# 2003    21.06
# 2004    21.05
# 2005    21.58
# 2006    20.64
# 2007    21.49
# 2008    21.53
# 2009    20.99
# 2010    22.07
# 2011    22.10
# 2012    21.77
# 2013    21.26
# 2014    21.15
# 2015    21.06
# 2016    21.13
# 2017    21.28
# 2018    21.41
# 2019    21.56
# 2020    21.66
# 2021    21.77
# 2022    21.89
# 2023    22.04
# 2024    22.19
# 2025    22.39
# 2026    22.51
# 2027    22.65
# 2028    22.78
# 2029    22.91
# 2030    23.06
# 2031    23.19
# 2032    23.30
# 2033    23.43
# 2034    23.56
# 2035    23.69
# Name: TOTAL, Length: 56, dtype: float64

# %%
NG_result.NaturalGas
# Out:
# Year
# 1980    4.79
# 1981    4.57
# 1982    4.68
# 1983    4.45
# 1984    4.64
# 1985    4.51
# 1986    4.38
# 1987    4.40
# 1988    4.72
# 1989    4.88
# 1990    4.47
# 1991    4.64
# 1992    4.78
# 1993    5.05
# 1994    4.94
# 1995    4.94
# 1996    5.35
# 1997    5.09
# 1998    4.64
# 1999    4.82
# 2000    5.07
# 2001    4.87
# 2002    4.98
# 2003    5.20
# 2004    4.97
# 2005    4.94
# 2006    4.46
# 2007    4.83
# 2008    5.00
# 2009    4.88
# 2010    5.06
# 2011    5.05
# 2012    5.17
# 2013    4.99
# 2014    5.00
# 2015    4.99
# 2016    4.98
# 2017    4.98
# 2018    4.96
# 2019    4.95
# 2020    4.95
# 2021    4.93
# 2022    4.92
# 2023    4.90
# 2024    4.89
# 2025    4.88
# 2026    4.87
# 2027    4.86
# 2028    4.85
# 2029    4.85
# 2030    4.84
# 2031    4.83
# 2032    4.81
# 2033    4.79
# 2034    4.78
# 2035    4.76
# Name: NaturalGas, Length: 56, dtype: float64

# %%
result.NaturalGas_perc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-11e1e6c047ae> in <module>()
# ----> 1 result.NaturalGas_perc
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'NaturalGas_perc'

# %%
# Regression Test-- Should be R^2= 1.00 since the independent variables add to TOTAL.
#df name: Res_Primary_E_Consumption
#http://allendowney.blogspot.com/
# from http://allendowney.blogspot.com/
#NaturalGas Petroleum TOTAL
import statsmodels.formula.api as smf
model = smf.ols('TOTAL ~ NaturalGas + Petroleum + Renewable + Electricity_Total', data=Res_Primary_E_Consumption)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  TOTAL   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.510e+06
# Date:                Fri, 24 Oct 2014   Prob (F-statistic):          1.11e-128
# Time:                        17:59:51   Log-Likelihood:                 196.34
# No. Observations:                  56   AIC:                            -382.7
# Df Residuals:                      51   BIC:                            -372.6
# Df Model:                           4
# ...
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept             0.0365      0.041      0.897      0.374        -0.045     0.118
# ...

# %%
result.NaturalGas
# Out:
# Year
# 1980    4.79
# 1981    4.57
# 1982    4.68
# 1983    4.45
# 1984    4.64
# 1985    4.51
# 1986    4.38
# 1987    4.40
# 1988    4.72
# 1989    4.88
# 1990    4.47
# 1991    4.64
# 1992    4.78
# 1993    5.05
# 1994    4.94
# 1995    4.94
# 1996    5.35
# 1997    5.09
# 1998    4.64
# 1999    4.82
# 2000    5.07
# 2001    4.87
# 2002    4.98
# 2003    5.20
# 2004    4.97
# 2005    4.94
# 2006    4.46
# 2007    4.83
# 2008    5.00
# 2009    4.88
# 2010    5.06
# 2011    5.05
# 2012    5.17
# 2013    4.99
# 2014    5.00
# 2015    4.99
# 2016    4.98
# 2017    4.98
# 2018    4.96
# 2019    4.95
# 2020    4.95
# 2021    4.93
# 2022    4.92
# 2023    4.90
# 2024    4.89
# 2025    4.88
# 2026    4.87
# 2027    4.86
# 2028    4.85
# 2029    4.85
# 2030    4.84
# 2031    4.83
# 2032    4.81
# 2033    4.79
# 2034    4.78
# 2035    4.76
# Name: NaturalGas, Length: 56, dtype: float64

# %%
result.TOTAL.plot()
# linear increase since modeled after 2010.
# but hits later

# %%
NaturalGas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-f945291bbd47> in <module>()
# ----> 1 NaturalGas
#
# NameError: name 'NaturalGas' is not defined

# %%
result.Natural Gas.plot()
# linear increase since modeled after 2010.
# but hits later
# Out:
#   File "<ipython-input-23-f092ae17272d>", line 1
#     result.Natural Gas.plot()
#                      ^
# SyntaxError: invalid syntax

# %%
#idf
# he gets summary view
idf[-50:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-abf940390dc1> in <module>()
#       1 #idf
#       2 # he gets summary view
# ----> 3 idf[-50:]
#
# NameError: name 'idf' is not defined

# %%
#idf
# he gets summary view
#idf[-50:]
# name and year are part of the row index.
idf.ix['Travis']
#plot
idf.ix['Travis'].prop.plot()
#also diversity of names factors in.
# dataset only has top 1000

# people got excited about Travis around 1908 then it trailed off

# %%
# name and year are part of the row index.
#idf.ix['Ella']
#plot
#idf.ix['Ella'].prop.plot()
#also diversity of names factors in.
# dataset only has top 1000

# Ella faded over time. Then it came back in 2000
# From 1.2% of names to 0.2% of names.


idf.ix['Talia'].prop.plot()

# %%
#how to get Number of Ella's born in 2005?

# how to chart against Talia's?

# %%
#boys[boys.name == 'Travis']
#Dataframe of Travis over time.
#long comparison.
#index the data frame by name and year.
idf = boys.set_index(['name', 'year'])

# %%
#idf.ix['John']
#or
idf.ix['John', 1880]
# Out:
# prop       0.081541
# sex             boy
# soundex        J500
# Name: (John, 1880), dtype: object

# %%
#idf.ix['Ella']
#or
idf.ix['Ella', 1880]
# Out:
#           prop   sex soundex  year_rank
# year
# 1880  0.011843  girl    E400      988.0
# 1881  0.011612  girl    E400      988.0
# 1882  0.010423  girl    E400      986.0
# 1883  0.010419  girl    E400      985.0
# 1884  0.009986  girl    E400      982.0
# 1885  0.009827  girl    E400      982.0
# 1886  0.009522  girl    E400      982.0
# 1887  0.009786  girl    E400      985.0
# 1888  0.009364  girl    E400      983.0
# 1889  0.008704  girl    E400      979.0
# 1890  0.008717  girl    E400      978.0
# 1891  0.008572  girl    E400      978.0
# 1892  0.008038  girl    E400      974.0
# 1893  0.007814  girl    E400      973.0
# 1894  0.007463  girl    E400      970.0
# 1895  0.006851  girl    E400      966.0
# 1896  0.006679  girl    E400      965.0
# 1897  0.006879  girl    E400      965.0
# 1898  0.006256  girl    E400      962.0
# 1899  0.006069  girl    E400      959.0
# 1900  0.006011  girl    E400      959.0
# 1901  0.005644  girl    E400      959.0
# ...

# %%
#idf.ix['Ella']
#or
idf.ix['Ella', 2005]
# Out:
# prop         0.004473
# sex              girl
# soundex          E400
# year_rank         978
# Name: (Ella, 2005), dtype: object

# %%
#idf.ix['Talia']
#or
idf.ix['Talia', 2005]
#none in 1880
# none in 2009?
# or not in the top 1000 in 2009?
# Out:
# prop         0.000437
# sex              girl
# soundex          T400
# year_rank         647
# Name: (Talia, 2005), dtype: object

# %%
#girls[boys.name == 'Ella']
#Dataframe of Ella over time.
#long comparison.
#index the data frame by name and year.
idf = girls.set_index(['name', 'year'])

# %%
names
# Out:
#         year      name      prop   sex soundex
# 0       1880      John  0.081541   boy    J500
# 1       1880   William  0.080511   boy    W450
# 2       1880     James  0.050057   boy    J520
# 3       1880   Charles  0.045167   boy    C642
# 4       1880    George  0.043292   boy    G620
# 5       1880     Frank  0.027380   boy    F652
# 6       1880    Joseph  0.022229   boy    J210
# 7       1880    Thomas  0.021401   boy    T520
# 8       1880     Henry  0.020641   boy    H560
# 9       1880    Robert  0.020404   boy    R163
# 10      1880    Edward  0.019965   boy    E363
# 11      1880     Harry  0.018175   boy    H600
# 12      1880    Walter  0.014822   boy    W436
# 13      1880    Arthur  0.013504   boy    A636
# 14      1880      Fred  0.013251   boy    F630
# 15      1880    Albert  0.012609   boy    A416
# 16      1880    Samuel  0.008648   boy    S540
# 17      1880     David  0.007339   boy    D130
# 18      1880     Louis  0.006993   boy    L200
# ...

# %%
girls[girls.name == 'Ella']
#Dataframe of Ella over time.
#long comparison.
#index the data frame by name and year.
#idf = girls.set_index(['name', 'year'])
# Out:
#         year  name      prop   sex soundex  year_rank
# 129012  1880  Ella  0.011843  girl    E400      988.0
# 130012  1881  Ella  0.011612  girl    E400      988.0
# 131014  1882  Ella  0.010423  girl    E400      986.0
# 132015  1883  Ella  0.010419  girl    E400      985.0
# 133018  1884  Ella  0.009986  girl    E400      982.0
# 134018  1885  Ella  0.009827  girl    E400      982.0
# 135018  1886  Ella  0.009522  girl    E400      982.0
# 136015  1887  Ella  0.009786  girl    E400      985.0
# 137017  1888  Ella  0.009364  girl    E400      983.0
# 138021  1889  Ella  0.008704  girl    E400      979.0
# 139022  1890  Ella  0.008717  girl    E400      978.0
# 140022  1891  Ella  0.008572  girl    E400      978.0
# 141026  1892  Ella  0.008038  girl    E400      974.0
# 142027  1893  Ella  0.007814  girl    E400      973.0
# 143030  1894  Ella  0.007463  girl    E400      970.0
# 144034  1895  Ella  0.006851  girl    E400      966.0
# ...

# %%
girls[girls.name == 'Ella'].plot()
#Dataframe of Ella over time.
#long comparison.
#index the data frame by name and year.
#idf = girls.set_index(['name', 'year'])

# %%
#boys.groupby('name')['prop'].mean()
#mean proportion by nameb
#boys.groupby('name')['prop'].mean().order()
# a series method
#? how to reverse the order?

boys.groupby('name')['prop'].describe()
#summary for each name
# a series method.
# Out:
# name
# Aaden  count    1.000000
#        mean     0.000442
#        std           NaN
#        min      0.000442
#        25%      0.000442
#        50%      0.000442
#        75%      0.000442
#        max      0.000442
# Aarav  count    1.000000
#        mean     0.000101
#        std           NaN
#        min      0.000101
#        25%      0.000101
#        50%      0.000101
#        75%      0.000101
# ...
# Zion    mean     0.000490
#         std      0.000165
#         min      0.000119
#         25%      0.000419
#         50%      0.000482
#         75%      0.000558
#         max      0.000731
# Zollie  count    8.000000
#         mean     0.000060
#         std      0.000012
#         min      0.000049
#         25%      0.000053
#         50%      0.000055
#         75%      0.000061
#         max      0.000087
# Length: 27496, dtype: float64

# %%
#boys['prop'].describe()
#with scipy installed
#array of prop-- a simple summary output.
#max value.
#can invoke it on the subgroups.
#indexed by the unique names.
#table summary to groups of the data.
result = boys.groupby('year')['prop'].describe()

# %%
result[:50]
#why no table for me (at 1:55)
# https://www.youtube.com/watch?v=w26x-z-BdWQ
# Out:
# year
# 1880  count    1000.000000
#       mean        0.000931
#       std         0.004871
#       min         0.000042
#       25%         0.000059
#       50%         0.000118
#       75%         0.000372
#       max         0.081541
# 1881  count    1000.000000
#       mean        0.000930
#       std         0.004812
#       min         0.000037
#       25%         0.000065
#       50%         0.000120
#       75%         0.000369
#       max         0.080975
# 1882  count    1000.000000
#       mean        0.000928
#       std         0.004691
#       min         0.000041
#       25%         0.000066
#       50%         0.000115
#       75%         0.000377
#       max         0.078314
# 1883  count    1000.000000
#       mean        0.000929
#       std         0.004675
#       min         0.000044
#       25%         0.000062
#       50%         0.000116
#       75%         0.000382
#       max         0.079066
# 1884  count    1000.000000
#       mean        0.000927
# ...

# %%
#rank of name
#change over time
#diversity of names
#boys.groupby('year').size()
# most popular for each year.
boys.groupby('year').size()

# many options-- number of unique records in the year column
# Out:
# year
# 1880    1000
# 1881    1000
# 1882    1000
# 1883    1000
# 1884    1000
# 1885    1000
# 1886    1000
# 1887    1000
# 1888    1000
# 1889    1000
# 1890    1000
# 1891    1000
# 1892    1000
# 1893    1000
# 1894    1000
# ...
# 1994    1000
# 1995    1000
# 1996    1000
# 1997    1000
# 1998    1000
# 1999    1000
# 2000    1000
# 2001    1000
# 2002    1000
# 2003    1000
# 2004    1000
# 2005    1000
# 2006    1000
# 2007    1000
# 2008    1000
# Length: 129, dtype: int64

# %%
df = boys[boys.year == 2008].sort_index(by='prop',ascending=False)
#sort in descending order- prop
#df.prop

#take cum. sum.
##df.prop.cumsum()
#top 1000 names represent 80% of the names in 2008.
#top n names-- sort from high to low-
# how many to get to 50%?
## old: df.prop.cumsum().searchsorted(0.5)
#uses numpy
#You are probably using a version that is 0.13.0 or later where Series now subclasses NDFrame, you have to now do this to return a numpy array:
# error: prop_cumsum.values.searchsorted(0.5)

# error: prop.cumsum.values.searchsorted(0.5)

df.prop.values.cumsum().searchsorted(0.5)

#using advice from:
# http://stackoverflow.com/questions/21822988/what-series-method-replaced-searchsorted/21832478#21832478
# Out:
# 127

# %%
# to check it.
#df.prop.cumsum()
#80% of names

df.prop.cumsum()[:130]
#first 130 
# measure of diversity
# Out:
# 128000    0.010355
# 128001    0.019792
# 128002    0.029093
# 128003    0.037892
# 128004    0.046594
# 128005    0.055160
# 128006    0.063602
# 128007    0.072040
# 128008    0.080308
# 128009    0.088369
# 128010    0.096246
# 128011    0.103940
# 128012    0.111510
# 128013    0.118977
# 128014    0.126239
# ...
# 128115    0.481593
# 128116    0.483275
# 128117    0.484921
# 128118    0.486563
# 128119    0.488203
# 128120    0.489818
# 128121    0.491429
# 128122    0.493032
# 128123    0.494626
# 128124    0.496173
# 128125    0.497718
# 128126    0.499243
# 128127    0.500748
# 128128    0.502243
# 128129    0.503723
# Name: prop, Length: 130, dtype: float64

# %%
df = boys[boys.year == 1880].sort_index(by='prop',ascending=False)
#sort in descending order- prop
#df.prop

#take cum. sum.
##df.prop.cumsum()
#top 1000 names represent 80% of the names in 2008.
#top n names-- sort from high to low-
# how many to get to 50%?
## old: df.prop.cumsum().searchsorted(0.5)
#uses numpy
#You are probably using a version that is 0.13.0 or later where Series now subclasses NDFrame, you have to now do this to return a numpy array:
# error: prop_cumsum.values.searchsorted(0.5)

# error: prop.cumsum.values.searchsorted(0.5)

df.prop.values.cumsum().searchsorted(0.5)



#using advice from:
# http://stackoverflow.com/questions/21822988/what-series-method-replaced-searchsorted/21832478#21832478
# Out:
# 15

# %%
# attempt1
def get_quantile_count(group, quantile =0.5):
    df = group.sort_index(by='prop', ascending=False)
    return df.prop.cumsum().searchsorted(quantile)
boys.groupby('year').apply(get_quantile_count).plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-8c5fd5877b75> in <module>()
#       3     df = group.sort_index(by='prop', ascending=False)
#       4     return df.prop.cumsum().searchsorted(quantile)
# ----> 5 boys.groupby('year').apply(get_quantile_count).plot()
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     635             return func(g, *args, **kwargs)
#     636
# --> 637         return self._python_apply_general(f)
#     638
#     639     def _python_apply_general(self, f):
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     639     def _python_apply_general(self, f):
#     640         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# ...

# %% [markdown]
# ###### Big difference above-- only 15 names made up 50% of the population.
# versus 127 in 2008.
# # at 2:01

# %%
# attempt2
import numpy as np
def get_quantile_count(group, quantile =0.5):
    df = group.sort_index(by='prop', ascending=False)
    return np.searchsorted(df.prop.cumsum().values, my_new_value)
boys.groupby('year').apply(get_quantile_count).plot()

# advice from here:
# https://stackoverflow.com/questions/21822988/what-series-method-replaced-searchsorted
# my_new_value????
# why can I not comment on Github?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-e0c52708215a> in <module>()
#       4     df = group.sort_index(by='prop', ascending=False)
#       5     return np.searchsorted(df.prop.cumsum().values, my_new_value)
# ----> 6 boys.groupby('year').apply(get_quantile_count).plot()
#       7
#       8 # advice from here:
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     635             return func(g, *args, **kwargs)
#     636
# --> 637         return self._python_apply_general(f)
#     638
#     639     def _python_apply_general(self, f):
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     639     def _python_apply_general(self, f):
#     640         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# ...

# %%
# attempt3
import numpy as np
def get_quantile_count(group, quantile =0.5):
    df = group.sort_index(by='prop', ascending=False)
    #return np.searchsorted(df.prop.cumsum().values, my_new_value)
boys.groupby('year').apply(get_quantile_count).plot()

# advice from here:
# https://stackoverflow.com/questions/21822988/what-series-method-replaced-searchsorted
# my_new_value????
# why can I not comment on SOflow?
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-24-d2bce1353c36> in <module>()
#       4     df = group.sort_index(by='prop', ascending=False)
#       5     #return np.searchsorted(df.prop.cumsum().values, my_new_value)
# ----> 6 boys.groupby('year').apply(get_quantile_count).plot()
#       7
#       8 # advice from here:
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     635             return func(g, *args, **kwargs)
#     636
# --> 637         return self._python_apply_general(f)
#     638
#     639     def _python_apply_general(self, f):
#
# /home/perry/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     642
#     643         return self._wrap_applied_output(keys, values,
# ...

# %%
# attempt3
import numpy as np
def get_quantile_count(group, quantile =0.5):
    df = group.sort_index(by='prop', ascending=False)
    return df.prop.cumsum().searchsorted(quantile)
boy_ct.boys.groupby('year').apply(get_quantile_count)
girl_ct = girls.groupby('year').apply(get_quantile_count)
boy_ct.plot(label='boy')
girl_ct.plot(label='girl')
legend(loc='best')
#cool function, if I could get the rest to work.
# in pylab mode only?
# name 'boy_ct' is not defined

# advice from here:
# https://stackoverflow.com/questions/21822988/what-series-method-replaced-searchsorted
# my_new_value????
# why can I not comment on SOflow?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-59e028264886> in <module>()
#       4     df = group.sort_index(by='prop', ascending=False)
#       5     return df.prop.cumsum().searchsorted(quantile)
# ----> 6 boy_ct.boys.groupby('year').apply(get_quantile_count)
#       7 girl_ct = girls.groupby('year').apply(get_quantile_count)
#       8 boy_ct.plot(label='boy')
#
# NameError: name 'boy_ct' is not defined

# %%
# attempt4
import numpy as np
def get_quantile_count(group, quantile =0.5):
    group =group.groupby ('soundex').sum()
    df = group.sort_index(by='prop', ascending=False)
    return df.prop.cumsum().searchsorted(quantile)
boy_ct.boys.groupby('year').apply(get_quantile_count)
girl_ct = girls.groupby('year').apply(get_quantile_count)
boy_ct.plot(label='boy')
girl_ct.plot(label='girl')
legend(loc='best')
#cool function, if I could get the rest to work.
# in pylab mode only?
# name 'boy_ct' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ef03a021fe4c> in <module>()
#       5     df = group.sort_index(by='prop', ascending=False)
#       6     return df.prop.cumsum().searchsorted(quantile)
# ----> 7 boy_ct.boys.groupby('year').apply(get_quantile_count)
#       8 girl_ct = girls.groupby('year').apply(get_quantile_count)
#       9 boy_ct.plot(label='boy')
#
# NameError: name 'boy_ct' is not defined

# %% [markdown]
# # not sure why this is not working

# %%
# attempt4
import numpy as np
def get_quantile_count(group, quantile =0.5):
    group =group.groupby ('soundex').sum()
    df = group.sort_index(by='prop', ascending=False)
    return df.prop.cumsum().searchsorted(quantile)
#f= lamba group: get_quantile_count(x,0.1)
q =0.25
    
boy_ct.boys.groupby('year').apply(get_quantile_count, quantile = q)
girl_ct = girls.groupby('year').apply(get_quantile_count)
boy_ct.plot(label='boy')
girl_ct.plot(label='girl')
legend(loc='best')
#cool function, if I could get the rest to work.
# in pylab mode only?
# name 'boy_ct' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-176cf66a6f65> in <module>()
#       8 q =0.25
#       9
# ---> 10 boy_ct.boys.groupby('year').apply(get_quantile_count, quantile = q)
#      11 girl_ct = girls.groupby('year').apply(get_quantile_count)
#      12 boy_ct.plot(label='boy')
#
# NameError: name 'boy_ct' is not defined

# %% [markdown]
# # What is the rank of your name?

# %%
boys[boys.year == 2008].prop.rank()
#number from 1-1000  assigns ties-- means of the ranks
# Out:
# 128000    1000
# 128001     999
# 128002     998
# 128003     997
# 128004     996
# 128005     995
# 128006     994
# 128007     993
# 128008     992
# 128009     991
# 128010     990
# 128011     989
# 128012     988
# 128013     987
# 128014     986
# ...
# 128985    16.0
# 128986    12.5
# 128987    12.5
# 128988    12.5
# 128989    12.5
# 128990     7.5
# 128991     7.5
# 128992     7.5
# 128993     7.5
# 128994     7.5
# 128995     7.5
# 128996     2.5
# 128997     2.5
# 128998     2.5
# 128999     2.5
# Name: prop, Length: 1000, dtype: float64

# %%
#boys[boys.year == 2008].prop.rank()
#number from 1-1000  assigns ties-- means of the ranks
# subset names over time

#boys.groupby('year').prop
# not working
#boys.groupby('year')

grouped = boys.groupby('year')['prop']
grouped.transform(Series.rank)
# rigid-- look at subgroup. call the function on it.
# requires that the result be the exact same size of the thing that it took.
#one dimensional array
# just integers.
# Out:
# 0     1000
# 1      999
# 2      998
# 3      997
# 4      996
# 5      995
# 6      994
# 7      993
# 8      992
# 9      991
# 10     990
# 11     989
# 12     988
# 13     987
# 14     986
# ...
# 128985    16.0
# 128986    12.5
# 128987    12.5
# 128988    12.5
# 128989    12.5
# 128990     7.5
# 128991     7.5
# 128992     7.5
# 128993     7.5
# 128994     7.5
# 128995     7.5
# 128996     2.5
# 128997     2.5
# 128998     2.5
# 128999     2.5
# Name: prop, Length: 129000, dtype: float64

# %%
# now rank of wes over time

grouped = boys.groupby('year')['prop']
boys['year_rank'] = grouped.transform(Series.rank)
boys[boys.name == 'Wesley'].year_rank.plot()

#
#-c:4: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
#Try using .loc[row_index,col_indexer] = value instead

# but still works, I guess.

# but my y axis is different. proportion rather than rank?

# %%
grouped = boys.groupby('year')['prop']
boys['year_rank'] = grouped.transform(Series.rank)
boys
# Out:
#         year       name      prop  sex soundex  year_rank
# 0       1880       John  0.081541  boy    J500     1000.0
# 1       1880    William  0.080511  boy    W450      999.0
# 2       1880      James  0.050057  boy    J520      998.0
# 3       1880    Charles  0.045167  boy    C642      997.0
# 4       1880     George  0.043292  boy    G620      996.0
# 5       1880      Frank  0.027380  boy    F652      995.0
# 6       1880     Joseph  0.022229  boy    J210      994.0
# 7       1880     Thomas  0.021401  boy    T520      993.0
# 8       1880      Henry  0.020641  boy    H560      992.0
# 9       1880     Robert  0.020404  boy    R163      991.0
# 10      1880     Edward  0.019965  boy    E363      990.0
# 11      1880      Harry  0.018175  boy    H600      989.0
# 12      1880     Walter  0.014822  boy    W436      988.0
# 13      1880     Arthur  0.013504  boy    A636      987.0
# 14      1880       Fred  0.013251  boy    F630      986.0
# ...

# %%
grouped = girls.groupby('year')['prop']
girls['year_rank'] = grouped.transform(Series.rank)
girls
# Out:
#         year       name      prop   sex soundex  year_rank
# 129000  1880       Mary  0.072381  girl    M600     1000.0
# 129001  1880       Anna  0.026678  girl    A500      999.0
# 129002  1880       Emma  0.020521  girl    E500      998.0
# 129003  1880  Elizabeth  0.019865  girl    E421      997.0
# 129004  1880     Minnie  0.017888  girl    M500      996.0
# 129005  1880   Margaret  0.016167  girl    M626      995.0
# 129006  1880        Ida  0.015081  girl    I300      994.0
# 129007  1880      Alice  0.014487  girl    A420      993.0
# 129008  1880     Bertha  0.013523  girl    B630      992.0
# 129009  1880      Sarah  0.013196  girl    S600      991.0
# 129010  1880      Annie  0.012888  girl    A500      990.0
# 129011  1880      Clara  0.012560  girl    C460      989.0
# 129012  1880       Ella  0.011843  girl    E400      988.0
# 129013  1880   Florence  0.010891  girl    F465      987.0
# 129014  1880       Cora  0.010706  girl    C600      986.0
# ...

# %%
grouped = boys.groupby('year')['prop']
boys['year_rank'] = grouped.transform(Series.rank)
idf = boys.set_index(['name', 'year']) 
# error. does not work.
#-c:3: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
#Try using .loc[row_index,col_indexer] = value instead
# Out:
# -c:3: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
#transform mutates the values within a group
grouped = boys.groupby('year')['prop']
#grouped.transform(lambda x: x *2)

#subtract the mean value to center each group.
#centering the values around the mean.

grouped.transform(lambda x: x -x.mean())
# or use apply but worse performance.
# Out:
# 0     0.080610
# 1     0.079580
# 2     0.049126
# 3     0.044236
# 4     0.042361
# 5     0.026449
# 6     0.021298
# 7     0.020470
# 8     0.019710
# 9     0.019473
# 10    0.019034
# 11    0.017244
# 12    0.013891
# 13    0.012573
# 14    0.012320
# ...
# 128985   -0.000703
# 128986   -0.000704
# 128987   -0.000704
# 128988   -0.000704
# 128989   -0.000704
# 128990   -0.000705
# 128991   -0.000705
# 128992   -0.000705
# 128993   -0.000705
# 128994   -0.000705
# 128995   -0.000705
# 128996   -0.000706
# 128997   -0.000706
# 128998   -0.000706
# 128999   -0.000706
# Name: prop, Length: 129000, dtype: float64

# %%
grouped = boys.groupby('year')['prop']
boys['year_rank'] = grouped.transform(Series.rank)
idf = boys.set_index(['name', 'year']) 
#idf.ix['Wesley']
idf.ix['Wesley'].year_rank.plot()
# or use matplotlib function.
# why showing only 800 to 940?-- misleading.

#this works, but with an error.
#-c:2: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
#Try using .loc[row_index,col_indexer] = value instead
# Out:
# -c:2: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
grouped = girls.groupby('year')['prop']
girls['year_rank'] = grouped.transform(Series.rank)
idf = girls.set_index(['name', 'year']) 
#idf.ix['Ella']
idf.ix['Ella'].year_rank.plot()
# or use matplotlib function.

# not clear why it dropped so much then came back.
# consider presenting as divided by 1000?
Better to show ranking?

# %%
grouped = girls.groupby('year')['prop']
girls['year_rank'] = grouped.transform(Series.rank)
idf = girls.set_index(['name', 'year']) 
#idf.ix['Talia']
idf.ix['Talia'].year_rank.plot()
# or use matplotlib function.
# why showing only 800 to 940-- misleading.

#this works, but with an error.
#-c:2: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
#Try using .loc[row_index,col_indexer] = value instead

# %%
grouped = girls.groupby('year')['prop']
girls['year_rank'] = grouped.transform(Series.rank)
idf = girls.set_index(['name', 'year']) 
#idf.ix['Carrie']
idf.ix['Carrie'].year_rank.plot()

# %%
grouped = boys.groupby('year')['prop']
boys['year_rank'] = grouped.transform(Series.rank)
idf = boys.set_index(['name', 'year']) 
#idf.ix['Perry']
idf.ix['Perry'].year_rank.plot()

# %%
grouped = girls.groupby('year')['prop']
girls['year_rank'] = grouped.transform(Series.rank)
idf = girls.set_index(['name', 'year']) 
#idf.ix['Perry']
idf.ix['Perry'].year_rank.plot()

# none?
# Out:
# /home/perry/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py:2544: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1883.0, right=1883.0
#   'left=%s, right=%s') % (left, right))

# %%
#transform mutates the values within a group
grouped = boys.groupby('year')['prop']
#grouped.transform(lambda x: x *2)

#subtract the mean value to center each group.
#centering the values around the mean.

result = grouped.transform(lambda x: x -x.mean())

# no longer a dataframe
result.groupby(boys.year).mean()
# pass the array of values.

# should show values of 0. rounding issue for me?
# Out:
# year
# 1880   -9.300286e-19
# 1881   -6.732895e-19
# 1882   -4.959141e-19
# 1883   -5.418842e-19
# 1884   -4.317293e-19
# 1885   -2.032445e-18
# 1886    2.077548e-18
# 1887   -2.081668e-19
# 1888   -8.324504e-19
# 1889   -2.281378e-18
# 1890    5.033951e-18
# 1891   -2.146720e-20
# 1892    5.661704e-19
# 1893    3.731173e-18
# 1894   -1.291285e-18
# ...
# 1994   -7.582910e-19
# 1995    8.890458e-19
# 1996    8.363536e-19
# 1997    2.785315e-19
# 1998   -2.836273e-19
# 1999    6.108395e-19
# 2000    5.882881e-19
# 2001    6.381614e-19
# 2002    2.998903e-19
# 2003   -1.147086e-19
# 2004   -8.933826e-20
# 2005    1.060350e-19
# 2006    2.114194e-19
# 2007    3.191891e-19
# 2008   -4.629543e-19
# Name: prop, Length: 129, dtype: float64

# %%
#same thing using apply
grouped = boys.groupby('year')['prop']
#grouped.transform(lambda x: x *2)

#subtract the mean value to center each group.
#centering the values around the mean.

result = grouped.apply(lambda x: x -x.mean())
#very general.
# no longer a dataframe
result.groupby(boys.year).mean()
# pass the array of values.

# should show values of 0. rounding issue for me?
# Out:
# year
# 1880   -9.300286e-19
# 1881   -6.732895e-19
# 1882   -4.959141e-19
# 1883   -5.418842e-19
# 1884   -4.317293e-19
# 1885   -2.032445e-18
# 1886    2.077548e-18
# 1887   -2.081668e-19
# 1888   -8.324504e-19
# 1889   -2.281378e-18
# 1890    5.033951e-18
# 1891   -2.146720e-20
# 1892    5.661704e-19
# 1893    3.731173e-18
# 1894   -1.291285e-18
# ...
# 1994   -7.582910e-19
# 1995    8.890458e-19
# 1996    8.363536e-19
# 1997    2.785315e-19
# 1998   -2.836273e-19
# 1999    6.108395e-19
# 2000    5.882881e-19
# 2001    6.381614e-19
# 2002    2.998903e-19
# 2003   -1.147086e-19
# 2004   -8.933826e-20
# 2005    1.060350e-19
# 2006    2.114194e-19
# 2007    3.191891e-19
# 2008   -4.629543e-19
# Length: 129, dtype: float64

# %%
# check runtime

#same thing using apply
grouped = boys.groupby('year')['prop']
#grouped.transform(lambda x: x *2)

#subtract the mean value to center each group.
#centering the values around the mean.

# %timeit result = grouped.apply(lambda x: x -x.mean())
#very general.
# no longer a dataframe
result.groupby(boys.year).mean()
# pass the array of values.

# should show values of 0. rounding issue for me?
# Out:
# 10 loops, best of 3: 23.4 ms per loop
# year
# 1880   -9.300286e-19
# 1881   -6.732895e-19
# 1882   -4.959141e-19
# 1883   -5.418842e-19
# 1884   -4.317293e-19
# 1885   -2.032445e-18
# 1886    2.077548e-18
# 1887   -2.081668e-19
# 1888   -8.324504e-19
# 1889   -2.281378e-18
# 1890    5.033951e-18
# 1891   -2.146720e-20
# 1892    5.661704e-19
# 1893    3.731173e-18
# 1894   -1.291285e-18
# ...
# 1994   -7.582910e-19
# 1995    8.890458e-19
# 1996    8.363536e-19
# 1997    2.785315e-19
# 1998   -2.836273e-19
# 1999    6.108395e-19
# 2000    5.882881e-19
# 2001    6.381614e-19
# 2002    2.998903e-19
# 2003   -1.147086e-19
# 2004   -8.933826e-20
# 2005    1.060350e-19
# 2006    2.114194e-19
# 2007    3.191891e-19
# 2008   -4.629543e-19
# Length: 129, dtype: float64

# %%
# check runtime

#same thing using apply
grouped = boys.groupby('year')['prop']
#grouped.transform(lambda x: x *2)

#subtract the mean value to center each group.
#centering the values around the mean.

# %timeit result = grouped.transform(lambda x: x -x.mean())
#very general.
# no longer a dataframe
result.groupby(boys.year).mean()
# pass the array of values.

# should show values of 0. rounding issue for me?
#same speeds for me -23.2 ms per loop.
# versus 15 ms and 46 ms for him
# he had 100 loops
# Out:
# 10 loops, best of 3: 23.2 ms per loop
# year
# 1880   -9.300286e-19
# 1881   -6.732895e-19
# 1882   -4.959141e-19
# 1883   -5.418842e-19
# 1884   -4.317293e-19
# 1885   -2.032445e-18
# 1886    2.077548e-18
# 1887   -2.081668e-19
# 1888   -8.324504e-19
# 1889   -2.281378e-18
# 1890    5.033951e-18
# 1891   -2.146720e-20
# 1892    5.661704e-19
# 1893    3.731173e-18
# 1894   -1.291285e-18
# ...
# 1994   -7.582910e-19
# 1995    8.890458e-19
# 1996    8.363536e-19
# 1997    2.785315e-19
# 1998   -2.836273e-19
# 1999    6.108395e-19
# 2000    5.882881e-19
# 2001    6.381614e-19
# 2002    2.998903e-19
# 2003   -1.147086e-19
# 2004   -8.933826e-20
# 2005    1.060350e-19
# 2006    2.114194e-19
# 2007    3.191891e-19
# 2008   -4.629543e-19
# Length: 129, dtype: float64

# %%
births = read_csv('births.csv')

# %%
names
# gives proportion, but not the total number of people.

# find total number of Johns born.
# Out:
#         year      name      prop   sex soundex
# 0       1880      John  0.081541   boy    J500
# 1       1880   William  0.080511   boy    W450
# 2       1880     James  0.050057   boy    J520
# 3       1880   Charles  0.045167   boy    C642
# 4       1880    George  0.043292   boy    G620
# 5       1880     Frank  0.027380   boy    F652
# 6       1880    Joseph  0.022229   boy    J210
# 7       1880    Thomas  0.021401   boy    T520
# 8       1880     Henry  0.020641   boy    H560
# 9       1880    Robert  0.020404   boy    R163
# 10      1880    Edward  0.019965   boy    E363
# 11      1880     Harry  0.018175   boy    H600
# 12      1880    Walter  0.014822   boy    W436
# 13      1880    Arthur  0.013504   boy    A636
# 14      1880      Fred  0.013251   boy    F630
# 15      1880    Albert  0.012609   boy    A416
# 16      1880    Samuel  0.008648   boy    S540
# 17      1880     David  0.007339   boy    D130
# 18      1880     Louis  0.006993   boy    L200
# ...

# %%
# pandas join function is merge
#merge?
merge(names, births, on= [ 'year', 'sex'])

#simple join on year and sex in both Df.
# do three different examples of this.
# Out:
#         year      name      prop   sex soundex   births
# 0       1880      John  0.081541   boy    J500   118405
# 1       1880   William  0.080511   boy    W450   118405
# 2       1880     James  0.050057   boy    J520   118405
# 3       1880   Charles  0.045167   boy    C642   118405
# 4       1880    George  0.043292   boy    G620   118405
# 5       1880     Frank  0.027380   boy    F652   118405
# 6       1880    Joseph  0.022229   boy    J210   118405
# 7       1880    Thomas  0.021401   boy    T520   118405
# 8       1880     Henry  0.020641   boy    H560   118405
# 9       1880    Robert  0.020404   boy    R163   118405
# 10      1880    Edward  0.019965   boy    E363   118405
# 11      1880     Harry  0.018175   boy    H600   118405
# 12      1880    Walter  0.014822   boy    W436   118405
# 13      1880    Arthur  0.013504   boy    A636   118405
# 14      1880      Fred  0.013251   boy    F630   118405
# 15      1880    Albert  0.012609   boy    A416   118405
# ...

# %% [markdown]
# ###### # note that many to many joins create the cartesian product of the two tables.

# %%
# many to many joins
# cartesion product of the duplicated keys.
# if you don't specify the merge keys, it uses the intersection of the columns as the merge key
# so could omit year and sex.

merge(names, births, on= [ 'year', 'sex'])
# Out:
#         year      name      prop   sex soundex   births
# 0       1880      John  0.081541   boy    J500   118405
# 1       1880   William  0.080511   boy    W450   118405
# 2       1880     James  0.050057   boy    J520   118405
# 3       1880   Charles  0.045167   boy    C642   118405
# 4       1880    George  0.043292   boy    G620   118405
# 5       1880     Frank  0.027380   boy    F652   118405
# 6       1880    Joseph  0.022229   boy    J210   118405
# 7       1880    Thomas  0.021401   boy    T520   118405
# 8       1880     Henry  0.020641   boy    H560   118405
# 9       1880    Robert  0.020404   boy    R163   118405
# 10      1880    Edward  0.019965   boy    E363   118405
# 11      1880     Harry  0.018175   boy    H600   118405
# 12      1880    Walter  0.014822   boy    W436   118405
# 13      1880    Arthur  0.013504   boy    A636   118405
# 14      1880      Fred  0.013251   boy    F630   118405
# 15      1880    Albert  0.012609   boy    A416   118405
# ...

# %%
merged = merge(names, births, on= [ 'year', 'sex'])

# %%
# total number,
# need to add the number of persons
merged['persons'] = np.floor(merged.prop * merged.births)

#decimal numbers so use npl.floor

# %%
merged.head()
# Out:
#    year     name      prop  sex soundex  births  persons
# 0  1880     John  0.081541  boy    J500  118405     9654
# 1  1880  William  0.080511  boy    W450  118405     9532
# 2  1880    James  0.050057  boy    J520  118405     5926
# 3  1880  Charles  0.045167  boy    C642  118405     5347
# 4  1880   George  0.043292  boy    G620  118405     5125

# %%
merged.groupby(['name','sex'])['persons'].sum()
#for each name sex combo-- the total number of births.
#hierarchical labeling.
# Out:
# name      sex
# Aaden     boy        959
# Aaliyah   girl     39660
# Aarav     boy        219
# Aaron     boy     508034
#           girl      1365
# Ab        boy         24
# Abagail   girl      2680
# Abb       boy         15
# Abbey     girl     14333
# Abbie     boy         10
#           girl     16556
# Abbigail  girl      6792
# Abbott    boy          9
# Abby      girl     47845
# Abdiel    boy        199
# ...
# Zilpah  girl        8
# Zilpha  girl       70
# Zina    girl     2263
# Zion    boy     11428
#         girl     1530
# Zita    girl      831
# Zoa     girl       73
# Zoe     girl    66271
# Zoey    girl    19335
# Zoie    girl     4688
# Zola    girl     4847
# Zollie  boy        60
# Zona    girl     3218
# Zora    girl     4551
# Zula    girl     3578
# Name: persons, Length: 7455, dtype: float64

# %%
# order for most popular names.

merged.groupby(['name','sex'])['persons'].sum().order()
#for each name sex combo-- the total number of births.
#hierarchical labeling.
# Out:
# name      sex
# Alabama   girl    3
# Daisye    girl    3
# Crissie   girl    3
# Dollye    girl    3
# Dema      girl    3
# Chestina  girl    3
# Ala       girl    3
# Clem      girl    3
# Chester   girl    3
# Eithel    girl    3
# Amey      girl    3
# Achsah    girl    3
# Alfred    girl    3
# Esequiel  boy     4
# Amil      boy     4
# ...
# Elizabeth    girl    1540430
# Patricia     girl    1567602
# Daniel       boy     1776483
# Christopher  boy     1924919
# Thomas       boy     2239606
# Charles      boy     2320818
# Joseph       boy     2490274
# Richard      boy     2535681
# David        boy     3495940
# William      boy     3951365
# Mary         girl    4097626
# Michael      boy     4207352
# Robert       boy     4752198
# John         boy     5016124
# James        boy     5021269
# Name: persons, Length: 7455, dtype: float64

# %% [markdown]
# ### Try to find specific names

# %%
# from above.
boys[boys.name == 'Wesley'].year_rank.plot()

# %%
boys[boys.name == 'Wesley'].year_rank

# case numbers shown.
# Out:
# 108      892.0
# 1118     883.0
# 2101     899.5
# 3121     879.0
# 4120     880.0
# 5127     873.0
# 6120     880.5
# 7115     885.0
# 8112     888.0
# 9146     855.5
# 10116    884.0
# 11119    881.0
# 12119    881.0
# 13118    882.0
# 14112    888.0
# ...
# 114117    883.0
# 115128    872.0
# 116136    864.0
# 117143    857.0
# 118151    848.5
# 119167    833.5
# 120170    830.0
# 121183    816.5
# 122182    818.0
# 123183    817.0
# 124183    817.0
# 125188    812.5
# 126189    811.0
# 127194    806.0
# 128193    807.0
# Name: year_rank, Length: 129, dtype: float64

# %%
# Ella
girls[girls.name == 'Ella'].year_rank.plot()

# %%
# Ella
girls[girls.name == 'Ella'].year_rank
# Out:
# 129012    988
# 130012    988
# 131014    986
# 132015    985
# 133018    982
# 134018    982
# 135018    982
# 136015    985
# 137017    983
# 138021    979
# 139022    978
# 140022    978
# 141026    974
# 142027    973
# 143030    970
# ...
# 243687    312.5
# 244700    299.0
# 245599    398.5
# 246499    500.5
# 247412    588.0
# 248373    627.5
# 249264    736.0
# 250191    809.0
# 251088    912.0
# 252043    957.0
# 253028    972.0
# 254022    978.0
# 255020    980.0
# 256020    980.0
# 257018    982.0
# Name: year_rank, Length: 124, dtype: float64

# %%
#boys[boys.year== 2000].prop.idxmax()
# gives the index of the maximum value: idmax
girls.ix[girls[girls.year== 2000].prop.idxmax()]
# for the whole row
# Out:
# year             2000
# name            Emily
# prop         0.013017
# sex              girl
# soundex          E540
# year_rank        1000
# Name: 249000, dtype: object

# %% [markdown]
# ###### From here:
#     http://nbviewer.ipython.org/github/joshplotkin/pandas-exercises/blob/master/BabyNames.ipynb

# %%
mboys = merge(boys, births)  # inner join by default.
mboys['persons'] = np.floor(mboys.prop * mboys.births)

# %%
persons = mboys.set_index(['year', 'name']).persons   # Select out persons

type(persons)  # One dimensional serie
# Out:
# pandas.core.series.Series

# %%
persons  # hierarchical index
# Out:
# year  name
# 1880  John       9654
#       William    9532
#       James      5926
#       Charles    5347
#       George     5125
#       Frank      3241
#       Joseph     2632
#       Thomas     2533
#       Henry      2443
#       Robert     2415
#       Edward     2363
#       Harry      2152
#       Walter     1754
#       Arthur     1598
#       Fred       1568
# ...
# 2008  Eliezer      199
#       Bronson      197
#       Cornelius    197
#       Pierre       197
#       Cortez       197
#       Baron        195
#       Carlo        195
#       Carsen       195
#       Fletcher     195
#       Izayah       195
#       Kolten       195
#       Damari       193
#       Hugh         193
#       Jensen       193
#       Yurem        193
# Name: persons, Length: 129000, dtype: float64

# %%
persons.unstack('name')   # Create a data frame whose columns are each unique names, and the row indexes are the years.
# Out:
# name  Aaden  Aarav  Aaron  Ab  Abb  Abbie  Abbott  Abdiel  Abdul  Abdullah  \
# year
# 1880    NaN    NaN    101   4  NaN    NaN       4     NaN    NaN       NaN
# 1881    NaN    NaN     93   4  NaN    NaN     NaN     NaN    NaN       NaN
# 1882    NaN    NaN     85   5  NaN    NaN     NaN     NaN    NaN       NaN
# 1883    NaN    NaN    104 NaN  NaN    NaN     NaN     NaN    NaN       NaN
# 1884    NaN    NaN     96 NaN    5    NaN     NaN     NaN    NaN       NaN
# 1885    NaN    NaN     88   6  NaN    NaN     NaN     NaN    NaN       NaN
# 1886    NaN    NaN     85 NaN  NaN    NaN     NaN     NaN    NaN       NaN
# 1887    NaN    NaN     78   5  NaN      5     NaN     NaN    NaN       NaN
# 1888    NaN    NaN     90 NaN  NaN    NaN       5     NaN    NaN       NaN
# 1889    NaN    NaN     84 NaN  NaN    NaN     NaN     NaN    NaN       NaN
# 1890    NaN    NaN     96 NaN    5    NaN     NaN     NaN    NaN       NaN
# ...

# %%
result = _   # underscore in ipython: the output of the last statement, because we don't want to compute again the same thing.

# %%
result
# Out:
# name  Aaden  Aarav  Aaron  Ab  Abb  Abbie  Abbott  Abdiel  Abdul  Abdullah  \
# year
# 1880    NaN    NaN    101   4  NaN    NaN       4     NaN    NaN       NaN
# 1881    NaN    NaN     93   4  NaN    NaN     NaN     NaN    NaN       NaN
# 1882    NaN    NaN     85   5  NaN    NaN     NaN     NaN    NaN       NaN
# 1883    NaN    NaN    104 NaN  NaN    NaN     NaN     NaN    NaN       NaN
# 1884    NaN    NaN     96 NaN    5    NaN     NaN     NaN    NaN       NaN
# 1885    NaN    NaN     88   6  NaN    NaN     NaN     NaN    NaN       NaN
# 1886    NaN    NaN     85 NaN  NaN    NaN     NaN     NaN    NaN       NaN
# 1887    NaN    NaN     78   5  NaN      5     NaN     NaN    NaN       NaN
# 1888    NaN    NaN     90 NaN  NaN    NaN       5     NaN    NaN       NaN
# 1889    NaN    NaN     84 NaN  NaN    NaN     NaN     NaN    NaN       NaN
# 1890    NaN    NaN     96 NaN    5    NaN     NaN     NaN    NaN       NaN
# ...

# %%
result['Wesley']
# Out:
# year
# 1880    123
# 1881    102
# 1882    144
# 1883    104
# 1884    120
# 1885    107
# 1886    120
# 1887    114
# 1888    147
# 1889    100
# 1890    130
# 1891    114
# 1892    141
# 1893    136
# 1894    149
# ...
# 1994    3030
# 1995    2795
# 1996    2616
# 1997    2355
# 1998    2240
# 1999    2208
# 2000    2217
# 2001    2024
# 2002    2049
# 2003    2116
# 2004    2103
# 2005    2107
# 2006    2096
# 2007    2057
# 2008    2050
# Name: Wesley, Length: 129, dtype: float64

# %%
result['Wesley'].plot()

# %%
result['Tom'].plot()

# %%
mgirls = merge(girls, births)  # inner join by default.

# %%
mgirls['persons'] = np.floor(mgirls.prop * mgirls.births)

# %%
gpersons = mgirls.set_index(['year', 'name']).persons   # Select out persons

# %%
type(gpersons)  # One dimensional series.
# Out:
# pandas.core.series.Series

# %%
gpersons  # hierarhical index
# Out:
# year  name
# 1880  Mary         7064
#       Anna         2603
#       Emma         2002
#       Elizabeth    1938
#       Minnie       1745
#       Margaret     1577
#       Ida          1471
#       Alice        1414
#       Bertha       1319
#       Sarah        1288
#       Annie        1257
#       Clara        1225
#       Ella         1155
#       Florence     1063
#       Cora         1044
# ...
# 2008  Neveah      269
#       Amaris      267
#       Hadassah    267
#       Dania       267
#       Hailie      267
#       Jamiya      267
#       Kathy       267
#       Laylah      267
#       Riya        267
#       Diya        265
#       Carleigh    265
#       Iyana       265
#       Kenley      263
#       Sloane      263
#       Elianna     263
# Name: persons, Length: 129000, dtype: float64

# %%
gpersons.unstack('name')   # Create a data frame whose columns are each unique names, and the row indexes are the years.
# Out:
# name  Aaliyah  Aaron  Abagail  Abbey  Abbie  Abbigail  Abby  Abigail  Abigale  \
# year
# 1880      NaN    NaN      NaN    NaN     70       NaN     5       12      NaN
# 1881      NaN    NaN      NaN    NaN     80       NaN     7        8      NaN
# 1882      NaN    NaN      NaN    NaN     79       NaN    10       13      NaN
# 1883      NaN    NaN      NaN    NaN     79       NaN   NaN       11      NaN
# 1884      NaN    NaN      NaN    NaN     97       NaN     6       12      NaN
# 1885      NaN    NaN      NaN    NaN     88       NaN   NaN        8      NaN
# 1886      NaN    NaN      NaN    NaN     83       NaN     7       15      NaN
# 1887      NaN    NaN      NaN    NaN    103       NaN   NaN       13      NaN
# 1888      NaN    NaN      NaN    NaN    136       NaN     9       17      NaN
# 1889      NaN    NaN      NaN    NaN    106       NaN     7       20      NaN
# 1890      NaN    NaN      NaN    NaN    139       NaN   NaN        9      NaN
# ...

# %%
result = _   # underscore in ipython: the output of the last statement, because we don't want to compute again the same thing.

# %%
result
# Out:
# name  Aaliyah  Aaron  Abagail  Abbey  Abbie  Abbigail  Abby  Abigail  Abigale  \
# year
# 1880      NaN    NaN      NaN    NaN     70       NaN     5       12      NaN
# 1881      NaN    NaN      NaN    NaN     80       NaN     7        8      NaN
# 1882      NaN    NaN      NaN    NaN     79       NaN    10       13      NaN
# 1883      NaN    NaN      NaN    NaN     79       NaN   NaN       11      NaN
# 1884      NaN    NaN      NaN    NaN     97       NaN     6       12      NaN
# 1885      NaN    NaN      NaN    NaN     88       NaN   NaN        8      NaN
# 1886      NaN    NaN      NaN    NaN     83       NaN     7       15      NaN
# 1887      NaN    NaN      NaN    NaN    103       NaN   NaN       13      NaN
# 1888      NaN    NaN      NaN    NaN    136       NaN     9       17      NaN
# 1889      NaN    NaN      NaN    NaN    106       NaN     7       20      NaN
# 1890      NaN    NaN      NaN    NaN    139       NaN   NaN        9      NaN
# ...

# %%
result['Ella']
# Out:
# year
# 1880    1155
# 1881    1147
# 1882    1205
# 1883    1250
# 1884    1373
# 1885    1394
# 1886    1463
# 1887    1520
# 1888    1774
# 1889    1646
# 1890    1757
# 1891    1685
# 1892    1807
# 1893    1760
# 1894    1761
# ...
# 1994     305
# 1995     299
# 1996     379
# 1997     494
# 1998     644
# 1999     764
# 2000    1215
# 2001    1715
# 2002    3553
# 2003    5897
# 2004    8232
# 2005    9056
# 2006    9196
# 2007    9522
# 2008    9321
# Name: Ella, Length: 129, dtype: float64

# %%
result['Ella'].plot()
